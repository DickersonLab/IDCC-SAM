# %%
import torch
import torchvision
import shutil
import sys
import os
os.chdir('/content')
print("PyTorch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("CUDA is available:", torch.cuda.is_available())

# !{sys.executable} -m pip install npsam

if not os.path.isdir('/content/Sample_images'):
  # !wget -N https://gitlab.au.dk/disorder/np-sam/-/archive/main/np-sam-main.zip?path=examples/Sample_images
  # !unzip /content/np-sam-main.zip?path=examples%2FSample_images
  shutil.move('/content/np-sam-main-examples-Sample_images/examples/Sample_images', '/content/Sample_images')
  # !rm /content/np-sam-main.zip?path=examples%2FSample_images
  # !rm -rf /content/np-sam-main-examples-Sample_images

from npsam import *
# Out:
# PyTorch version: 2.3.0+cu121
# Torchvision version: 0.18.0+cu121
# CUDA is available: True
# Collecting npsam
#   Downloading npsam-1.5.1-py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: numba==0.58.1 in /usr/local/lib/python3.10/dist-packages (from npsam) (0.58.1)
# Collecting opencv-python==4.9.0.80 (from npsam)
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 23.6 MB/s eta 0:00:00
# Collecting pandas==2.1.4 (from npsam)
#   Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 76.5 MB/s eta 0:00:00
# Collecting matplotlib==3.8.2 (from npsam)
#   Downloading matplotlib-3.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 86.7 MB/s eta 0:00:00
# Collecting scikit-image==0.22.0 (from npsam)
#   Downloading scikit_image-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 74.0 MB/s eta 0:00:00
# Collecting ipympl==0.9.3 (from npsam)
#   Downloading ipympl-0.9.3-py2.py3-none-any.whl (511 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.6/511.6 kB 23.6 MB/s eta 0:00:00
# Collecting PyQt5==5.15.10 (from npsam)
#   Downloading PyQt5-5.15.10-cp37-abi3-manylinux_2_17_x86_64.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 28.2 MB/s eta 0:00:00
# Collecting ultralytics==8.1.2 (from npsam)
#   Downloading ultralytics-8.1.2-py3-none-any.whl (699 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.7/699.7 kB 11.6 MB/s eta 0:00:00
# Collecting jupyterlab==4.0.10 (from npsam)
#   Downloading jupyterlab-4.0.10-py3-none-any.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 11.3 MB/s eta 0:00:00
# Collecting clip==0.2.0 (from npsam)
#   Downloading clip-0.2.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting piexif==1.1.3 (from npsam)
#   Downloading piexif-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting rosettasciio==0.1 (from npsam)
#   Downloading rosettasciio-0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (990 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.3/990.3 kB 69.4 MB/s eta 0:00:00
# Collecting parse==1.20.1 (from npsam)
#   Downloading parse-1.20.1-py2.py3-none-any.whl (20 kB)
# Collecting h5py==3.10.0 (from npsam)
#   Downloading h5py-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 103.0 MB/s eta 0:00:00
# Collecting tifffile==2024.1.30 (from npsam)
#   Downloading tifffile-2024.1.30-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.1/224.1 kB 35.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py==3.10.0->npsam) (1.25.2)
# Requirement already satisfied: ipython<9 in /usr/local/lib/python3.10/dist-packages (from ipympl==0.9.3->npsam) (7.34.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipympl==0.9.3->npsam) (0.2.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from ipympl==0.9.3->npsam) (9.4.0)
# Requirement already satisfied: traitlets<6 in /usr/local/lib/python3.10/dist-packages (from ipympl==0.9.3->npsam) (5.7.1)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /usr/local/lib/python3.10/dist-packages (from ipympl==0.9.3->npsam) (7.7.1)
# Collecting async-lru>=1.0.0 (from jupyterlab==4.0.10->npsam)
#   Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from jupyterlab==4.0.10->npsam) (5.5.6)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.10/dist-packages (from jupyterlab==4.0.10->npsam) (3.1.4)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.10/dist-packages (from jupyterlab==4.0.10->npsam) (5.7.2)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab==4.0.10->npsam)
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 10.8 MB/s eta 0:00:00
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab==4.0.10->npsam)
#   Downloading jupyter_server-2.14.1-py3-none-any.whl (383 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.4/383.4 kB 41.4 MB/s eta 0:00:00
# Collecting jupyterlab-server<3,>=2.19.0 (from jupyterlab==4.0.10->npsam)
#   Downloading jupyterlab_server-2.27.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.10/dist-packages (from jupyterlab==4.0.10->npsam) (0.2.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from jupyterlab==4.0.10->npsam) (24.1)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from jupyterlab==4.0.10->npsam) (2.0.1)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab==4.0.10->npsam) (6.3.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.2->npsam) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.2->npsam) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.2->npsam) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.2->npsam) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.2->npsam) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.2->npsam) (2.8.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba==0.58.1->npsam) (0.41.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4->npsam) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4->npsam) (2024.1)
# Collecting PyQt5-sip<13,>=12.13 (from PyQt5==5.15.10->npsam)
#   Downloading PyQt5_sip-12.13.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl (338 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.1/338.1 kB 38.1 MB/s eta 0:00:00
# Collecting PyQt5-Qt5>=5.15.2 (from PyQt5==5.15.10->npsam)
#   Downloading PyQt5_Qt5-5.15.2-py3-none-manylinux2014_x86_64.whl (59.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: dask[array]>=2021.3.1 in /usr/local/lib/python3.10/dist-packages (from rosettasciio==0.1->npsam) (2023.8.1)
# Requirement already satisfied: imageio>=2.16 in /usr/local/lib/python3.10/dist-packages (from rosettasciio==0.1->npsam) (2.31.6)
# Collecting pint>=0.8 (from rosettasciio==0.1->npsam)
#   Downloading Pint-0.24.1-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.3/301.3 kB 37.5 MB/s eta 0:00:00
# Collecting python-box<7,>=6 (from rosettasciio==0.1->npsam)
#   Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 92.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from rosettasciio==0.1->npsam) (6.0.1)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from rosettasciio==0.1->npsam) (1.11.4)
# Collecting sparse (from rosettasciio==0.1->npsam)
#   Downloading sparse-0.15.4-py2.py3-none-any.whl (237 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.3/237.3 kB 33.9 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.22.0->npsam) (3.3)
# Requirement already satisfied: lazy_loader>=0.3 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.22.0->npsam) (0.4)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.1.2->npsam) (2.31.0)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.1.2->npsam) (2.3.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.1.2->npsam) (0.18.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.1.2->npsam) (4.66.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.1.2->npsam) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.1.2->npsam) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics==8.1.2->npsam)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.1.2->npsam) (0.13.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from async-lru>=1.0.0->jupyterlab==4.0.10->npsam) (4.12.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask[array]>=2021.3.1->rosettasciio==0.1->npsam) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask[array]>=2021.3.1->rosettasciio==0.1->npsam) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask[array]>=2021.3.1->rosettasciio==0.1->npsam) (2023.6.0)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask[array]>=2021.3.1->rosettasciio==0.1->npsam) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[array]>=2021.3.1->rosettasciio==0.1->npsam) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask[array]>=2021.3.1->rosettasciio==0.1->npsam) (7.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl==0.9.3->npsam) (67.7.2)
# Collecting jedi>=0.16 (from ipython<9->ipympl==0.9.3->npsam)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 90.3 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl==0.9.3->npsam) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl==0.9.3->npsam) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl==0.9.3->npsam) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl==0.9.3->npsam) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl==0.9.3->npsam) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl==0.9.3->npsam) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython<9->ipympl==0.9.3->npsam) (4.9.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9,>=7.6.0->ipympl==0.9.3->npsam) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9,>=7.6.0->ipympl==0.9.3->npsam) (3.0.11)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyterlab==4.0.10->npsam) (6.1.12)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=3.0.3->jupyterlab==4.0.10->npsam) (2.1.5)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (3.7.1)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (23.1.0)
# Collecting jupyter-client (from ipykernel->jupyterlab==4.0.10->npsam)
#   Downloading jupyter_client-8.6.2-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 16.6 MB/s eta 0:00:00
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam)
#   Downloading jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (6.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (5.10.4)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam)
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (0.20.0)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (24.0.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (1.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core->jupyterlab==4.0.10->npsam) (4.2.2)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.10->npsam) (2.15.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.10->npsam)
#   Downloading json5-0.9.25-py3-none-any.whl (30 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.10->npsam) (4.19.2)
# Collecting appdirs>=1.4.4 (from pint>=0.8->rosettasciio==0.1->npsam)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting flexcache>=0.3 (from pint>=0.8->rosettasciio==0.1->npsam)
#   Downloading flexcache-0.3-py3-none-any.whl (13 kB)
# Collecting flexparser>=0.3 (from pint>=0.8->rosettasciio==0.1->npsam)
#   Downloading flexparser-0.3.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib==3.8.2->npsam) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.1.2->npsam) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.1.2->npsam) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.1.2->npsam) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.1.2->npsam) (2024.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.1.2->npsam) (3.15.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.1.2->npsam) (1.12.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8.0->ultralytics==8.1.2->npsam)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8.0->ultralytics==8.1.2->npsam)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8.0->ultralytics==8.1.2->npsam)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.8.0->ultralytics==8.1.2->npsam)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8.0->ultralytics==8.1.2->npsam)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8.0->ultralytics==8.1.2->npsam)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8.0->ultralytics==8.1.2->npsam)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8.0->ultralytics==8.1.2->npsam)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8.0->ultralytics==8.1.2->npsam)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.8.0->ultralytics==8.1.2->npsam)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8.0->ultralytics==8.1.2->npsam)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics==8.1.2->npsam) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics==8.1.2->npsam)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 73.0 MB/s eta 0:00:00
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (1.2.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (21.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask[array]>=2021.3.1->rosettasciio==0.1->npsam) (3.19.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython<9->ipympl==0.9.3->npsam) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.10->npsam) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.10->npsam) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.10->npsam) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.10->npsam) (0.18.1)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam)
#   Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (2.20.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask[array]>=2021.3.1->rosettasciio==0.1->npsam) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython<9->ipympl==0.9.3->npsam) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl==0.9.3->npsam) (0.2.13)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl==0.9.3->npsam) (6.5.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics==8.1.2->npsam) (1.3.0)
# Collecting fqdn (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.10->npsam)
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.10->npsam)
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.10->npsam)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting uri-template (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.10->npsam)
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: webcolors>=1.11 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.10->npsam) (24.6.0)
# Collecting jupyter-client (from ipykernel->jupyterlab==4.0.10->npsam)
#   Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl==0.9.3->npsam) (1.6.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl==0.9.3->npsam) (1.1.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.0.10->npsam) (2.22)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.10->npsam)
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 11.1 MB/s eta 0:00:00
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.10->npsam)
#   Downloading types_python_dateutil-2.9.0.20240316-py3-none-any.whl (9.7 kB)
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-0.2.0-py3-none-any.whl size=6989 sha256=c19490a307f3d06ddcf698ff1b563bc38fc1952fa337cad250cef73a19030fea
#   Stored in directory: /root/.cache/pip/wheels/7f/5c/e6/2c0fdb453a3569188864b17e9676bea8b3b7e160c037117869
# Successfully built clip
# Installing collected packages: PyQt5-Qt5, parse, clip, appdirs, uri-template, types-python-dateutil, tifffile, rfc3986-validator, rfc3339-validator, python-json-logger, python-box, PyQt5-sip, piexif, overrides, opencv-python, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, jsonpointer, json5, jedi, h5py, fqdn, flexparser, flexcache, async-lru, sparse, scikit-image, PyQt5, pint, pandas, nvidia-cusparse-cu12, nvidia-cudnn-cu12, matplotlib, jupyter-server-terminals, jupyter-client, arrow, nvidia-cusolver-cu12, isoduration, rosettasciio, thop, jupyter-events, ultralytics, jupyter-server, jupyterlab-server, jupyter-lsp, jupyterlab, ipympl, npsam
#   Attempting uninstall: tifffile
#     Found existing installation: tifffile 2024.6.18
#     Uninstalling tifffile-2024.6.18:
#       Successfully uninstalled tifffile-2024.6.18
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.2.0
#     Uninstalling python-box-7.2.0:
#       Successfully uninstalled python-box-7.2.0
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.8.0.76
#     Uninstalling opencv-python-4.8.0.76:
#       Successfully uninstalled opencv-python-4.8.0.76
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.19.3
#     Uninstalling scikit-image-0.19.3:
#       Successfully uninstalled scikit-image-0.19.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.24.0
#     Uninstalling jupyter-server-1.24.0:
#       Successfully uninstalled jupyter-server-1.24.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 2.1.4 which is incompatible.
# Successfully installed PyQt5-5.15.10 PyQt5-Qt5-5.15.2 PyQt5-sip-12.13.0 appdirs-1.4.4 arrow-1.3.0 async-lru-2.0.4 clip-0.2.0 flexcache-0.3 flexparser-0.3.1 fqdn-1.5.1 h5py-3.10.0 ipympl-0.9.3 isoduration-20.11.0 jedi-0.19.1 json5-0.9.25 jsonpointer-3.0.0 jupyter-client-7.4.9 jupyter-events-0.10.0 jupyter-lsp-2.2.5 jupyter-server-2.14.1 jupyter-server-terminals-0.5.3 jupyterlab-4.0.10 jupyterlab-server-2.27.2 matplotlib-3.8.2 npsam-1.5.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 opencv-python-4.9.0.80 overrides-7.7.0 pandas-2.1.4 parse-1.20.1 piexif-1.1.3 pint-0.24.1 python-box-6.1.0 python-json-logger-2.0.7 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rosettasciio-0.1 scikit-image-0.22.0 sparse-0.15.4 thop-0.1.1.post2209072238 tifffile-2024.1.30 types-python-dateutil-2.9.0.20240316 ultralytics-8.1.2 uri-template-1.3.0
# --2024-06-28 16:10:43--  https://gitlab.au.dk/disorder/np-sam/-/archive/main/np-sam-main.zip?path=examples/Sample_images
# Resolving gitlab.au.dk (gitlab.au.dk)... 185.45.20.19
# Connecting to gitlab.au.dk (gitlab.au.dk)|185.45.20.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘np-sam-main.zip?path=examples%2FSample_images’
#
# np-sam-main.zip?pat     [         <=>        ]   9.70M  2.17MB/s    in 5.3s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-06-28 16:10:50 (1.83 MB/s) - ‘np-sam-main.zip?path=examples%2FSample_images’ saved [10172816]
#
# Archive:  /content/np-sam-main.zip?path=examples%2FSample_images
# fd01a5a284eb345779393d85799ef0b2238700f7
#    creating: np-sam-main-examples-Sample_images/
#    creating: np-sam-main-examples-Sample_images/examples/
#    creating: np-sam-main-examples-Sample_images/examples/Sample_images/
#  extracting: np-sam-main-examples-Sample_images/examples/Sample_images/AgCuIrPdPt_HAADF.png
#  extracting: np-sam-main-examples-Sample_images/examples/Sample_images/Ag_HAADF.png
#  extracting: np-sam-main-examples-Sample_images/examples/Sample_images/PdCu_BF_TEM.png
#  extracting: np-sam-main-examples-Sample_images/examples/Sample_images/PdCu_BF_TEM_binned2x2.png
#  extracting: np-sam-main-examples-Sample_images/examples/Sample_images/PdCu_HAADF.png

# %% [markdown]
# Upload the image(s) to to the content folder and set a pathname called `filepath` to a file or a folder of the filetype .png, .jpg, .jpeg, .tif, .tiff (either an absolute or relative pathname)

# %% [markdown]
# Call the `SAM` function from `NPSAM.py` to get masks from the image. The function takes a filepath as the first argument and the following keyword arguments:<br>
#  - `device` (str): Can be either `cuda` or `cpu` (`default='cpu'`). <br>
#  - `PPS` (int): Sets the sampling gridsize for the image (`default=64`). <br>
#  - `SAM_model` (str): Chooses which SAM weights to use. Can either be `'f'` for [FastSAM](https://github.com/CASIA-IVA-Lab/FastSAM), `'h'` for huge, `'l'` for large, `'b'` for base or `'auto'` which chooses the largest of the three regular SAM weights availabe. (`default='auto'`) <br>
#  - `shape_filter` (bool): Removes faulty masks for a better and faster experience. However, for concave NPs it might cause problems (`default=True`) <br>
#  - `min_masks_region_area` (int): Sets the minimum mask area in pixels. Makes SAM faster but will miss NPs smaller than threshold (`default=35`) <br>
#  - `crop_and_enlarge` (bool): If `True`, it crops the image into 4 slightly overlapping parts that are also zoomed in (e.g., a 512x512 image is cropped to 4 680x680 images (340x340 before zoom), and runs SAM on all 4. Afterwards, the masks are stiched back together (`default=False`). <br>
#  - `invert` (bool): If `True`, the image is inverted before running SAM. The masks are saved as usual (`default=False`). <br>
#  - `double` (bool): If `True`, the original and inverted image will be segmented and stitched together. <br>
#  - `**kwargs`: More key word arguments can be applied see [documentation](https://github.com/facebookresearch/segment-anything/blob/main/segment_anything/automatic_mask_generator.py#L35) of the model.
#
# When executing `SAM` a folder `<filename>_files` is created next to the file(s).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path to the folder containing the images
filepath = '/content/drive/MyDrive/Final IDCC-SAM/Dataset/Rebuttal/VGG/Test_NP-SAM/'

#filepath_test = '/content/drive/MyDrive/Final IDCC-SAM/Dataset/Rebuttal/VGG/Test/images2'

# %%
SAM(filepath_test, device='cuda', PPS=64, SAM_model='h')
# Out:
# SAM weights were not found. This is probably because it is the first time running NP-SAM with this option.
#
# Do you want to download the huge weights file (size: 2.5 GB)? y/n: y
# sam_vit_h_4b8939.pth: 100%|██████████| 2.39G/2.39G [03:01<00:00, 14.1MiB/s]
# File downloaded successfully: /usr/local/lib/python3.10/dist-packages/npsam/sam_vit_h_4b8939.pth
# 54 masks found. It took 32 seconds

# %% [markdown]
# If `SAM` has already been executed once it is not necessary to segment the image again, as the masks have previously been saved in the folder `<filename>_files`, that it unless you want to redo it with other parameters.

# %% [markdown]
# Run NP-SAM

# %%
import pandas as pd
from io import StringIO
import sys

# Define the Capturing class to capture output
class Capturing(list):
    def __enter__(self):
        self._stdout = sys.stdout
        self._stderr = sys.stderr
        sys.stdout = self._stringio = StringIO()
        sys.stderr = StringIO()
        return self

    def __exit__(self, *args):
        self.extend(self._stringio.getvalue().splitlines())
        sys.stdout = self._stdout
        sys.stderr = self._stderr

# Run the SAM function and capture its output
with Capturing() as output:
    SAM(filepath, device='cuda', PPS=64, SAM_model='h')

# Print captured output for debugging
for line in output:
    print(line)

# Initialize a list to store image names and mask counts
results = []

# Variables to store current image name
current_image_name = None

# Process the captured output
for line in output:
    if "Now working on" in line:
        # Extract image name
        parts = line.split(' ')
        current_image_name = parts[-1]
    elif "masks found" in line and current_image_name:
        # Extract number of masks
        parts = line.split(' ')
        num_masks = int(parts[0])
        # Append result with current image name and mask count
        results.append({"image_name": current_image_name, "num_masks": num_masks})
        # Reset current_image_name for next iteration
        current_image_name = None

# Create a pandas DataFrame from the results list
df = pd.DataFrame(results)

# Save the DataFrame to an Excel file
df.to_excel("/content/drive/MyDrive/Final IDCC-SAM/Rebuttal/VGG/NP-SAM/NP-SAM_prediction_summary_VGG_draft.xlsx", index=False)

# Print DataFrame to debug
print(df)
# Out:
# The huge SAM weight (sam_vit_h_4b8939.pth) were chosen.
# 1/40 - Now working on: Copy of 170cell
# 95 masks found. It took 29 seconds
# 2/40 - Now working on: Copy of 169cell
# 83 masks found. It took 29 seconds
# 3/40 - Now working on: Copy of 168cell
# 80 masks found. It took 28 seconds
# 4/40 - Now working on: Copy of 167cell
# 75 masks found. It took 27 seconds
# 5/40 - Now working on: Copy of 166cell
# 79 masks found. It took 28 seconds
# 6/40 - Now working on: Copy of 165cell
# 102 masks found. It took 29 seconds
# 7/40 - Now working on: Copy of 164cell
# 124 masks found. It took 29 seconds
# 8/40 - Now working on: Copy of 163cell
# 105 masks found. It took 29 seconds
# 9/40 - Now working on: Copy of 162cell
# 112 masks found. It took 29 seconds
# 10/40 - Now working on: Copy of 161cell
# 94 masks found. It took 28 seconds
# 11/40 - Now working on: Copy of 200cell
# 82 masks found. It took 27 seconds
# 12/40 - Now working on: Copy of 199cell
# 95 masks found. It took 28 seconds
# 13/40 - Now working on: Copy of 198cell
# 62 masks found. It took 26 seconds
# 14/40 - Now working on: Copy of 197cell
# 125 masks found. It took 30 seconds
# 15/40 - Now working on: Copy of 196cell
# 69 masks found. It took 27 seconds
# 16/40 - Now working on: Copy of 195cell
# 104 masks found. It took 29 seconds
# 17/40 - Now working on: Copy of 194cell
# 81 masks found. It took 28 seconds
# 18/40 - Now working on: Copy of 193cell
# 108 masks found. It took 29 seconds
# 19/40 - Now working on: Copy of 192cell
# 75 masks found. It took 28 seconds
# 20/40 - Now working on: Copy of 191cell
# 95 masks found. It took 29 seconds
# 21/40 - Now working on: Copy of 181cell
# 64 masks found. It took 27 seconds
# 22/40 - Now working on: Copy of 190cell
# 114 masks found. It took 29 seconds
# 23/40 - Now working on: Copy of 187cell
# 84 masks found. It took 28 seconds
# 24/40 - Now working on: Copy of 186cell
# 94 masks found. It took 28 seconds
# 25/40 - Now working on: Copy of 189cell
# 73 masks found. It took 27 seconds
# 26/40 - Now working on: Copy of 185cell
# 106 masks found. It took 29 seconds
# 27/40 - Now working on: Copy of 178cell
# 104 masks found. It took 29 seconds
# 28/40 - Now working on: Copy of 179cell
# 113 masks found. It took 29 seconds
# 29/40 - Now working on: Copy of 180cell
# 69 masks found. It took 28 seconds
# 30/40 - Now working on: Copy of 171cell
# 96 masks found. It took 28 seconds
# 31/40 - Now working on: Copy of 174cell
# 90 masks found. It took 28 seconds
# 32/40 - Now working on: Copy of 177cell
# 86 masks found. It took 28 seconds
# 33/40 - Now working on: Copy of 175cell
# 73 masks found. It took 28 seconds
# 34/40 - Now working on: Copy of 172cell
# 90 masks found. It took 28 seconds
# 35/40 - Now working on: Copy of 173cell
# 123 masks found. It took 29 seconds
# 36/40 - Now working on: Copy of 176cell
# 64 masks found. It took 27 seconds
# 37/40 - Now working on: Copy of 188cell
# 90 masks found. It took 28 seconds
# 38/40 - Now working on: Copy of 184cell
# 114 masks found. It took 29 seconds
# 39/40 - Now working on: Copy of 183cell
# 119 masks found. It took 29 seconds
# 40/40 - Now working on: Copy of 182cell
# 102 masks found. It took 29 seconds
#    image_name  num_masks
# 0     170cell         95
# 1     169cell         83
# 2     168cell         80
# 3     167cell         75
# 4     166cell         79
# 5     165cell        102
# 6     164cell        124
# 7     163cell        105
# 8     162cell        112
# 9     161cell         94
# 10    200cell         82
# 11    199cell         95
# 12    198cell         62
# 13    197cell        125
# 14    196cell         69
# 15    195cell        104
# 16    194cell         81
# 17    193cell        108
# 18    192cell         75
# 19    191cell         95
# 20    181cell         64
# 21    190cell        114
# 22    187cell         84
# 23    186cell         94
# 24    189cell         73
# 25    185cell        106
# 26    178cell        104
# 27    179cell        113
# 28    180cell         69
# 29    171cell         96
# 30    174cell         90
# 31    177cell         86
# 32    175cell         73
# 33    172cell         90
# 34    173cell        123
# 35    176cell         64
# 36    188cell         90
# 37    184cell        114
# 38    183cell        119
# 39    182cell        102

# %% [markdown]
# Compute Raw MAE and AAE

# %%
import pandas as pd

# Paths to the files
result_excel_path = "/content/drive/MyDrive/Final IDCC-SAM/Rebuttal/VGG/NP-SAM/NP-SAM_prediction_summary_VGG_draft.xlsx"
ground_truth_csv_path = '/content/drive/MyDrive/Final IDCC-SAM/Dataset/Rebuttal/VGG/ground_truth.csv'

# Read the result DataFrame
result_df = pd.read_excel(result_excel_path)

# Read the ground truth DataFrame
ground_truth_df = pd.read_csv(ground_truth_csv_path)

# Remove the ".png" suffix from the "image name" column in the ground truth DataFrame
ground_truth_df['image name'] = ground_truth_df['image name'].str.replace('.png', '')

# Display the ground truth DataFrame to understand its structure
print("Ground Truth DataFrame after removing '.png':")
print(ground_truth_df.head())

# Merge the DataFrames on the "image_name" column
merged_df = result_df.merge(ground_truth_df, left_on='image_name', right_on='image name', how='left')

# Delete the "image_name" and "SN" columns
merged_df.drop(columns=['image_name', 'SN'], inplace=True)

# Rename "num_masks" to "Prediction"
merged_df.rename(columns={'num_masks': 'Prediction'}, inplace=True)
merged_df.rename(columns={'ground truth': 'Ground Truth'}, inplace=True)

# Calculate Raw Absolute Error
merged_df['Raw Absolute Error'] = (merged_df['Ground Truth'] - merged_df['Prediction']).abs()

# Determine AAE <= 10
merged_df['AAE <= 10'] = merged_df['Raw Absolute Error'].apply(lambda x: 'Yes' if x <= 10 else 'No')

# Rearrange columns
merged_df = merged_df[['image name', 'Ground Truth', 'Prediction', 'Raw Absolute Error', 'AAE <= 10']]

# Display the merged DataFrame to verify the result
print("Merged DataFrame:")
print(merged_df.head())

# Save the merged DataFrame to a new Excel file
merged_df.to_excel("/content/drive/MyDrive/Final IDCC-SAM/Rebuttal/VGG/NP-SAM/NP-SAM_prediction_summary_VGG_final.xlsx", index=False)

# Print a message to indicate completion
print("Merged DataFrame saved to NP-SAM_prediction_summary_VGG_final.xlsx")
# Out:
# Ground Truth DataFrame after removing '.png':
#    SN image name  ground truth
# 0   1    001cell           133
# 1   2    019cell           189
# 2   3    011cell           113
# 3   4    010cell           109
# 4   5    004cell            79
# Merged DataFrame:
#   image name  Ground Truth  Prediction  Raw Absolute Error AAE <= 10
# 0    170cell           153          95                  58        No
# 1    169cell           156          83                  73        No
# 2    168cell            94          80                  14        No
# 3    167cell           106          75                  31        No
# 4    166cell           141          79                  62        No
# Merged DataFrame saved to NP-SAM_prediction_summary_VGG_final.xlsx

# %% [markdown]
# For a quick visualisation images and masks can be plotted.

# %%
mask_plot(filepath)

# Save the generated plots
# Out:
# Output hidden; open in https://colab.research.google.com to view.
