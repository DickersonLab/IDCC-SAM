# %% [markdown]
# ## Mount GDrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Apply on Test Images

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd

# Define input and output folders
input_folder = '/content/drive/MyDrive/Final IDCC-SAM/Dataset/Rebuttal/IDCIA/Test/'
output_folder = '/content/drive/MyDrive/Final IDCC-SAM/Dataset/Rebuttal/IDCIA/Test_clahe/'

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Function to apply CLAHE preprocessing to an image and save it
def apply_clahe_and_save(input_image_path, output_image_path):
    # Read the original image
    original_image = cv2.imread(input_image_path)

    # Convert the image to grayscale
    gray_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)

    # Create a CLAHE object
    clahe = cv2.createCLAHE(clipLimit=8.0, tileGridSize=(8, 8))

    # Apply CLAHE to the grayscale image
    adaptive_equalized_image = clahe.apply(gray_image)

    # Convert the processed image back to BGR (if needed)
    adaptive_equalized_image_bgr = cv2.cvtColor(adaptive_equalized_image, cv2.COLOR_GRAY2BGR)

    # Save the processed image
    cv2.imwrite(output_image_path, adaptive_equalized_image_bgr)

# Apply CLAHE preprocessing to all images in the input folder and save them to the output folder
for filename in os.listdir(input_folder):
    input_image_path = os.path.join(input_folder, filename)
    output_image_path = os.path.join(output_folder, filename)
    apply_clahe_and_save(input_image_path, output_image_path)

# Select 3 random images for sanity check
random_images = np.random.choice(os.listdir(input_folder), 3, replace=False)

# Plot the original and processed images side by side
plt.figure(figsize=(12, 4))
for i, image_name in enumerate(random_images, 1):
    original_image = cv2.imread(os.path.join(input_folder, image_name))
    processed_image = cv2.imread(os.path.join(output_folder, image_name))

    plt.subplot(3, 2, 2*i-1)
    plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(3, 2, 2*i)
    plt.imshow(cv2.cvtColor(processed_image, cv2.COLOR_BGR2RGB))
    plt.title('Processed Image')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# Apply on Training Images

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd

# Define input and output folders
input_folder = '/content/drive/MyDrive/Final IDCC-SAM/Dataset/Rebuttal/IDCIA/Train/cell_images/'
output_folder = '/content/drive/MyDrive/Final IDCC-SAM/Dataset/Rebuttal/IDCIA/Train_clahe/images/'

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Function to apply CLAHE preprocessing to an image and save it
def apply_clahe_and_save(input_image_path, output_image_path):
    # Read the original image
    original_image = cv2.imread(input_image_path)

    # Convert the image to grayscale
    gray_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)

    # Create a CLAHE object
    clahe = cv2.createCLAHE(clipLimit=8.0, tileGridSize=(8, 8))

    # Apply CLAHE to the grayscale image
    adaptive_equalized_image = clahe.apply(gray_image)

    # Convert the processed image back to BGR (if needed)
    adaptive_equalized_image_bgr = cv2.cvtColor(adaptive_equalized_image, cv2.COLOR_GRAY2BGR)

    # Save the processed image
    cv2.imwrite(output_image_path, adaptive_equalized_image_bgr)

# Apply CLAHE preprocessing to all images in the input folder and save them to the output folder
for filename in os.listdir(input_folder):
    input_image_path = os.path.join(input_folder, filename)
    output_image_path = os.path.join(output_folder, filename)
    apply_clahe_and_save(input_image_path, output_image_path)

# Select 3 random images for sanity check
random_images = np.random.choice(os.listdir(input_folder), 3, replace=False)

# Plot the original and processed images side by side
plt.figure(figsize=(12, 4))
for i, image_name in enumerate(random_images, 1):
    original_image = cv2.imread(os.path.join(input_folder, image_name))
    processed_image = cv2.imread(os.path.join(output_folder, image_name))

    plt.subplot(3, 2, 2*i-1)
    plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(3, 2, 2*i)
    plt.imshow(cv2.cvtColor(processed_image, cv2.COLOR_BGR2RGB))
    plt.title('Processed Image')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# Convert all images from tiff to png

# %%
import os
import cv2

# Path to the folder containing the TIFF images
folder_path = '/content/drive/MyDrive/Final IDCC-SAM/Dataset/Rebuttal/IDCIA/Train_clahe/images/'

# Get the list of TIFF filenames
tiff_filenames = [f for f in os.listdir(folder_path) if f.lower().endswith('.tiff') or f.lower().endswith('.tif')]

# Loop through each TIFF image
for filename in tiff_filenames:
    # Load the TIFF image
    tiff_image_path = os.path.join(folder_path, filename)
    image = cv2.imread(tiff_image_path, cv2.IMREAD_UNCHANGED)

    # Construct the PNG image path
    png_image_name = os.path.splitext(filename)[0] + '.png'
    png_image_path = os.path.join(folder_path, png_image_name)

    # Save the image as PNG
    cv2.imwrite(png_image_path, image)

    # Optionally, remove the original TIFF file
    os.remove(tiff_image_path)

    print(f"Converted {filename} to {png_image_name}")

print("Conversion complete.")
# Out:
# Converted 220912_GFP-AHPC_C_Map2AB_F9_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_C_Map2AB_F9_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_C_Map2AB_F10_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_C_Map2AB_F10_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_Map2AB_F1_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_Map2AB_F1_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_Map2AB_F2_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_Map2AB_F2_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_Map2AB_F4_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_Map2AB_F4_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_Map2AB_F6_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_Map2AB_F6_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_Map2AB_F9_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_Map2AB_F9_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_Map2AB_F10_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_Map2AB_F10_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_Map2AB_F1_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_Map2AB_F1_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_Map2AB_F2_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_Map2AB_F2_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_Map2AB_F4_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_Map2AB_F4_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_Map2AB_F6_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_Map2AB_F6_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_Map2AB_F8_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_Map2AB_F8_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_Map2AB_F9_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_Map2AB_F9_Cy3_ND2_20x.png
# Converted 220909_GFP-AHPC_D_GFAP_F8_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_D_GFAP_F8_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_D_GFAP_F9_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_D_GFAP_F9_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_D_MAP2ab_F1_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_D_MAP2ab_F1_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_D_MAP2ab_F2_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_D_MAP2ab_F2_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_D_MAP2ab_F4_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_D_MAP2ab_F4_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_D_MAP2ab_F5_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_D_MAP2ab_F5_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_D_MAP2ab_F7_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_D_MAP2ab_F7_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_D_MAP2ab_F9_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_D_MAP2ab_F9_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_C_GFAP_F3_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_C_GFAP_F3_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_C_GFAP_F4_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_C_GFAP_F4_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_C_GFAP_F5_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_C_GFAP_F5_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_C_GFAP_F6_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_C_GFAP_F6_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_C_GFAP_F7_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_C_GFAP_F7_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_C_GFAP_F9_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_C_GFAP_F9_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_B_GFAP_F3_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_B_GFAP_F3_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_B_GFAP_F4_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_B_GFAP_F4_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_B_GFAP_F6_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_B_GFAP_F6_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_B_GFAP_F8_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_B_GFAP_F8_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_B_GFAP_F10_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_B_GFAP_F10_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_A_GFAP_F6_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_A_GFAP_F6_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_A_GFAP_F7_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_A_GFAP_F7_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_A_GFAP_F9_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_A_GFAP_F9_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_A_GFAP_F10_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_A_GFAP_F10_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_C_Nestin_F1_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_C_Nestin_F1_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_C_Nestin_F2_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_C_Nestin_F2_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_C_Nestin_F3_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_C_Nestin_F3_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_C_Nestin_F5_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_C_Nestin_F5_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_C_Nestin_F6_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_C_Nestin_F6_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_C_Nestin_F8_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_C_Nestin_F8_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_Nestin_F1_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_Nestin_F1_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_Nestin_F2_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_Nestin_F2_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_Nestin_F3_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_Nestin_F3_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_Nestin_F8_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_Nestin_F8_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_Nestin_F9_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_Nestin_F9_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_Nestin_F10_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_Nestin_F10_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_Nestin_F2_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_Nestin_F2_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_Nestin_F3_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_Nestin_F3_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_Nestin_F6_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_Nestin_F6_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_Nestin_F8_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_Nestin_F8_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_Nestin_F9_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_Nestin_F9_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_Nestin_F10_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_Nestin_F10_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_C_Map2AB_F2_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_C_Map2AB_F2_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_C_Map2AB_F5_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_C_Map2AB_F5_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_C_Map2AB_F7_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_C_Map2AB_F7_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_C_Map2AB_F8_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_C_Map2AB_F8_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_C_Map2AB_F9_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_C_Map2AB_F9_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_C_Map2AB_F10_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_C_Map2AB_F10_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_Map2AB_F1_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_Map2AB_F1_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_Map2AB_F2_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_Map2AB_F2_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_Map2AB_F4_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_Map2AB_F4_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_Map2AB_F6_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_Map2AB_F6_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_Map2AB_F9_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_Map2AB_F9_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_Map2AB_F10_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_Map2AB_F10_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_Map2AB_F1_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_Map2AB_F1_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_Map2AB_F2_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_Map2AB_F2_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_Map2AB_F4_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_Map2AB_F4_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_Map2AB_F6_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_Map2AB_F6_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_Map2AB_F8_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_Map2AB_F8_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_Map2AB_F9_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_Map2AB_F9_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_C_TuJ1_F1.1_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_C_TuJ1_F1.1_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_C_TuJ1_F1.2_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_C_TuJ1_F1.2_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_C_TuJ1_F3_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_C_TuJ1_F3_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_C_TuJ1_F4_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_C_TuJ1_F4_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_C_TuJ1_F8_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_C_TuJ1_F8_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_C_TuJ1_F9_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_C_TuJ1_F9_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_C_TuJ1_F10_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_C_TuJ1_F10_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_TuJ1_F1_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_TuJ1_F1_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_TuJ1_F4_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_TuJ1_F4_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_TuJ1_F5_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_TuJ1_F5_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_TuJ1_F8_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_TuJ1_F8_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_TuJ1_F9_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_TuJ1_F9_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_TuJ1_F10_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_B_TuJ1_F10_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_TuJ1_F3_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_TuJ1_F3_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_TuJ1_F5_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_TuJ1_F5_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_TuJ1_F6_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_TuJ1_F6_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_TuJ1_F7_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_TuJ1_F7_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_TuJ1_F8_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_TuJ1_F8_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_A_TuJ1_F9_DAPI_ND1_20x.tiff to 220912_GFP-AHPC_A_TuJ1_F9_DAPI_ND1_20x.png
# Converted 220909_GFP-AHPC_A_GFAP_F4_DAPI_ND1_20x.tiff to 220909_GFP-AHPC_A_GFAP_F4_DAPI_ND1_20x.png
# Converted 220912_GFP-AHPC_B_RIP_F9_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_RIP_F9_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_C_RIP_F1_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_C_RIP_F1_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_C_RIP_F2_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_C_RIP_F2_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_C_RIP_F4_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_C_RIP_F4_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_C_RIP_F5_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_C_RIP_F5_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_C_RIP_F6_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_C_RIP_F6_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_C_RIP_F7_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_C_RIP_F7_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_RIP_F1_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_RIP_F1_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_RIP_F2_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_RIP_F2_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_RIP_F4_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_RIP_F4_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_RIP_F6_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_RIP_F6_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_RIP_F7_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_RIP_F7_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_RIP_F10_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_RIP_F10_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_RIP_F6_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_RIP_F6_Cy3_ND2_20x.png
# Converted 220909_GFP-AHPC_C_Nestin_F6_Cy3_ND2_20x.tiff to 220909_GFP-AHPC_C_Nestin_F6_Cy3_ND2_20x.png
# Converted 220909_GFP-AHPC_C_Nestin_F8_Cy3_ND2_20x.tiff to 220909_GFP-AHPC_C_Nestin_F8_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_Nestin_F1_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_Nestin_F1_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_Nestin_F2_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_Nestin_F2_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_Nestin_F3_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_Nestin_F3_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_Nestin_F8_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_Nestin_F8_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_Nestin_F9_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_Nestin_F9_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_Nestin_F10_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_Nestin_F10_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_Nestin_F2_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_Nestin_F2_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_Nestin_F6_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_Nestin_F6_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_Nestin_F8_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_Nestin_F8_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_Nestin_F9_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_Nestin_F9_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_Nestin_F10_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_Nestin_F10_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_C_TuJ1_F8_Cy3_ND1_20x.tiff to 220912_GFP-AHPC_C_TuJ1_F8_Cy3_ND1_20x.png
# Converted 220912_GFP-AHPC_C_TuJ1_F9_Cy3_ND1_20x.tiff to 220912_GFP-AHPC_C_TuJ1_F9_Cy3_ND1_20x.png
# Converted 220912_GFP-AHPC_C_TuJ1_F10_Cy3_ND1_20x.tiff to 220912_GFP-AHPC_C_TuJ1_F10_Cy3_ND1_20x.png
# Converted 220912_GFP-AHPC_B_TuJ1_F1_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_TuJ1_F1_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_TuJ1_F4_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_TuJ1_F4_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_TuJ1_F5_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_TuJ1_F5_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_TuJ1_F8_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_TuJ1_F8_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_TuJ1_F9_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_TuJ1_F9_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_B_TuJ1_F10_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_B_TuJ1_F10_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_TuJ1_F3_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_TuJ1_F3_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_TuJ1_F5_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_TuJ1_F5_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_TuJ1_F6_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_TuJ1_F6_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_TuJ1_F7_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_TuJ1_F7_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_TuJ1_F8_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_TuJ1_F8_Cy3_ND2_20x.png
# Converted 220912_GFP-AHPC_A_TuJ1_F9_Cy3_ND2_20x.tiff to 220912_GFP-AHPC_A_TuJ1_F9_Cy3_ND2_20x.png
# Converted 220909_GFP-AHPC_C_Ki67_F8_Cy3_ND8_20x.tiff to 220909_GFP-AHPC_C_Ki67_F8_Cy3_ND8_20x.png
# Converted 220909_GFP-AHPC_C_Ki67_F9_Cy3_ND8_20x.tiff to 220909_GFP-AHPC_C_Ki67_F9_Cy3_ND8_20x.png
# Converted 220909_GFP-AHPC_B_Ki67_F3_Cy3_ND8_20x.tiff to 220909_GFP-AHPC_B_Ki67_F3_Cy3_ND8_20x.png
# Converted 220909_GFP-AHPC_B_Ki67_F5_Cy3_ND8_20x.tiff to 220909_GFP-AHPC_B_Ki67_F5_Cy3_ND8_20x.png
# Converted 220909_GFP-AHPC_B_Ki67_F6_Cy3_ND8_20x.tiff to 220909_GFP-AHPC_B_Ki67_F6_Cy3_ND8_20x.png
# Converted 220909_GFP-AHPC_B_Ki67_F8_Cy3_ND8_20x.tiff to 220909_GFP-AHPC_B_Ki67_F8_Cy3_ND8_20x.png
# Converted 220909_GFP-AHPC_B_Ki67_F9_Cy3_ND8_20x.tiff to 220909_GFP-AHPC_B_Ki67_F9_Cy3_ND8_20x.png
# Converted 220909_GFP-AHPC_B_Ki67_F10_Cy3_ND8_20x.tiff to 220909_GFP-AHPC_B_Ki67_F10_Cy3_ND8_20x.png
# Converted 220909_GFP-AHPC_A_Ki67_F1_CY3_ND8_20x.tiff to 220909_GFP-AHPC_A_Ki67_F1_CY3_ND8_20x.png
# Converted 220909_GFP-AHPC_A_Ki67_F2_CY3_ND8_20x.tiff to 220909_GFP-AHPC_A_Ki67_F2_CY3_ND8_20x.png
# Converted 220909_GFP-AHPC_A_Ki67_F3_CY3_ND8_20x.tiff to 220909_GFP-AHPC_A_Ki67_F3_CY3_ND8_20x.png
# Converted 220909_GFP-AHPC_A_Ki67_F4_CY3_ND8_20x.tiff to 220909_GFP-AHPC_A_Ki67_F4_CY3_ND8_20x.png
# Converted 220909_GFP-AHPC_A_Ki67_F7_CY3_ND8_20x.tiff to 220909_GFP-AHPC_A_Ki67_F7_CY3_ND8_20x.png
# Converted 220909_GFP-AHPC_A_Ki67_F9_CY3_ND8_20x.tiff to 220909_GFP-AHPC_A_Ki67_F9_CY3_ND8_20x.png
# Converted 220909_GFP-AHPC_C_GFAP_F7_Cy3_ND2_20x.tiff to 220909_GFP-AHPC_C_GFAP_F7_Cy3_ND2_20x.png
# Converted 220909_GFP-AHPC_C_GFAP_F9_Cy3_ND2_20x.tiff to 220909_GFP-AHPC_C_GFAP_F9_Cy3_ND2_20x.png
# Converted 220909_GFP-AHPC_B_GFAP_F2_Cy3_ND2_20x.tiff to 220909_GFP-AHPC_B_GFAP_F2_Cy3_ND2_20x.png
# Converted 220909_GFP-AHPC_B_GFAP_F3_Cy3_ND2_20x.tiff to 220909_GFP-AHPC_B_GFAP_F3_Cy3_ND2_20x.png
# Converted 220909_GFP-AHPC_B_GFAP_F4_Cy3_ND2_20x.tiff to 220909_GFP-AHPC_B_GFAP_F4_Cy3_ND2_20x.png
# Converted 220909_GFP-AHPC_B_GFAP_F6_Cy3_ND2_20x.tiff to 220909_GFP-AHPC_B_GFAP_F6_Cy3_ND2_20x.png
# Converted 220909_GFP-AHPC_B_GFAP_F8_Cy3_ND2_20x.tiff to 220909_GFP-AHPC_B_GFAP_F8_Cy3_ND2_20x.png
# Converted 220909_GFP-AHPC_B_GFAP_F10_Cy3_ND2_20x.tiff to 220909_GFP-AHPC_B_GFAP_F10_Cy3_ND2_20x.png
# Converted 220909_GFP-AHPC_A_GFAP_F4_Cy3_ND2_20x.tiff to 220909_GFP-AHPC_A_GFAP_F4_Cy3_ND2_20x.png
# Converted 220909_GFP-AHPC_A_GFAP_F6_Cy3_ND2_20x.tiff to 220909_GFP-AHPC_A_GFAP_F6_Cy3_ND2_20x.png
# Converted 220909_GFP-AHPC_A_GFAP_F7_Cy3_ND2_20x.tiff to 220909_GFP-AHPC_A_GFAP_F7_Cy3_ND2_20x.png
# Converted 220909_GFP-AHPC_A_GFAP_F9_Cy3_ND2_20x.tiff to 220909_GFP-AHPC_A_GFAP_F9_Cy3_ND2_20x.png
# Converted 220909_GFP-AHPC_A_GFAP_F10_Cy3_ND2_20x.tiff to 220909_GFP-AHPC_A_GFAP_F10_Cy3_ND2_20x.png
# Conversion complete.
